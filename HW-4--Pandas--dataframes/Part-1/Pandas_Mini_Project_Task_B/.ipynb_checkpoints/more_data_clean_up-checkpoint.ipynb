# %%
# Dependencies
import pandas as pd

# %%
# load CSV
csv_path = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
dirty_df = pd.read_csv(csv_path, low_memory = False)
dirty_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# 1                NaN             NaN  ...               NaN
# 2                NaN             NaN  ...               NaN
# 3                NaN             NaN  ...               NaN
# 4                NaN             NaN  ...               NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 0                    NaN                NaN              NaN            NaN
# 1                    NaN                NaN              NaN            1.0
# 2                    NaN                NaN              NaN            NaN
# 3                    NaN                NaN              NaN            NaN
# 4                    NaN                NaN              NaN            NaN
#
#    ResourceW3Schools  ResourceYouTube  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
#                               SchoolDegree              SchoolMajor  \
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN
#
#    StudentDebtOwe
# 0         20000.0
# 1             NaN
# 2             NaN
# 3          7000.0
# 4             NaN
#
# [5 rows x 113 columns]

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
narrow_df = dirty_df.iloc[:, [0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
narrow_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo BootcampName  BootcampPostSalary  BootcampRecommend  \
# 0                NaN          NaN                 NaN                NaN
# 1                NaN          NaN                 NaN                NaN
# 2                NaN          NaN                 NaN                NaN
# 3                NaN          NaN                 NaN                NaN
# 4                NaN          NaN                 NaN                NaN
#
#    ChildrenNumber                 CityPopulation  ...  \
# 0             NaN  between 100,000 and 1 million  ...
# 1             NaN  between 100,000 and 1 million  ...
# 2             NaN            more than 1 million  ...
# 3             NaN            more than 1 million  ...
# 4             NaN  between 100,000 and 1 million  ...
#
#                 CountryLive                        EmploymentField  \
# 0  United States of America      office and administrative support
# 1  United States of America                      food and beverage
# 2  United States of America                                finance
# 3  United States of America  arts, entertainment, sports, or media
# 4  United States of America                              education
#
#      EmploymentStatus  Gender HasChildren  HoursLearning   Income  \
# 0  Employed for wages    male         0.0           30.0  32000.0
# 1  Employed for wages    male         NaN           30.0  15000.0
# 2  Employed for wages    male         NaN           20.0  48000.0
# 3  Employed for wages  female         NaN           20.0  43000.0
# 4  Employed for wages  female         NaN           25.0   6000.0
#
#              JobRoleInterest                             SchoolDegree  \
# 0                        NaN           some college credit, no degree
# 1    Front-End Web Developer           some college credit, no degree
# 2                        NaN  high school diploma or equivalent (GED)
# 3    Front-End Web Developer                        bachelor's degree
# 4   Full-Stack Web Developer           some college credit, no degree
#
#                SchoolMajor
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3  Cinematography And Film
# 4                      NaN
#
# [5 rows x 21 columns]

# %%
# Change reading 0 and 1 to No and Yes, respectively
boolean_df = narrow_df.replace({0 : "No", 1 : "Yes"})
boolean_df.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo BootcampName  BootcampPostSalary BootcampRecommend  \
# 0               NaN          NaN                 NaN               NaN
# 1               NaN          NaN                 NaN               NaN
# 2               NaN          NaN                 NaN               NaN
# 3               NaN          NaN                 NaN               NaN
# 4               NaN          NaN                 NaN               NaN
#
#   ChildrenNumber                 CityPopulation  ...  \
# 0            NaN  between 100,000 and 1 million  ...
# 1            NaN  between 100,000 and 1 million  ...
# 2            NaN            more than 1 million  ...
# 3            NaN            more than 1 million  ...
# 4            NaN  between 100,000 and 1 million  ...
#
#                 CountryLive                        EmploymentField  \
# 0  United States of America      office and administrative support
# 1  United States of America                      food and beverage
# 2  United States of America                                finance
# 3  United States of America  arts, entertainment, sports, or media
# 4  United States of America                              education
#
#      EmploymentStatus  Gender HasChildren HoursLearning   Income  \
# 0  Employed for wages    male          No            30  32000.0
# 1  Employed for wages    male         NaN            30  15000.0
# 2  Employed for wages    male         NaN            20  48000.0
# 3  Employed for wages  female         NaN            20  43000.0
# 4  Employed for wages  female         NaN            25   6000.0
#
#              JobRoleInterest                             SchoolDegree  \
# 0                        NaN           some college credit, no degree
# 1    Front-End Web Developer           some college credit, no degree
# 2                        NaN  high school diploma or equivalent (GED)
# 3    Front-End Web Developer                        bachelor's degree
# 4   Full-Stack Web Developer           some college credit, no degree
#
#                SchoolMajor
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3  Cinematography And Film
# 4                      NaN
#
# [5 rows x 21 columns]

# %%
# Extract rows for only those who attended a bootcamp
attended_df = boolean_df.loc[boolean_df["AttendedBootcamp"] == "Yes", :]
attended_df.head()
# Out:
#       Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93   32.0              Yes            Yes                   No
# 97   26.0              Yes            Yes                  Yes
# 130  41.0              Yes            Yes                  Yes
# 159  26.0              Yes            Yes                   No
# 188  24.0              Yes             No                  NaN
#
#     BootcampLoanYesNo      BootcampName  BootcampPostSalary BootcampRecommend  \
# 93                 No    Codify Academy                 NaN                No
# 97                 No    DaVinci Coders             45000.0                No
# 130               Yes     Coder Foundry             75000.0               Yes
# 159                No  General Assembly                 NaN                No
# 188               Yes               NaN                 NaN                No
#
#     ChildrenNumber                 CityPopulation  ...  \
# 93             NaN  between 100,000 and 1 million  ...
# 97             NaN            more than 1 million  ...
# 130              3              less than 100,000  ...
# 159            NaN  between 100,000 and 1 million  ...
# 188            NaN  between 100,000 and 1 million  ...
#
#                   CountryLive                        EmploymentField  \
# 93   United States of America  arts, entertainment, sports, or media
# 97   United States of America                   software development
# 130  United States of America                   software development
# 159  United States of America                                    NaN
# 188                    Canada                                    NaN
#
#                          EmploymentStatus  Gender HasChildren HoursLearning  \
# 93           Self-employed business owner    male         NaN            20
# 97                     Employed for wages    male          No            10
# 130                    Employed for wages    male         Yes            30
# 159  Not working and not looking for work  female         NaN            30
# 188      Not working but looking for work  female         NaN            60
#
#       Income           JobRoleInterest                        SchoolDegree  \
# 93   67000.0                       NaN                   bachelor's degree
# 97   40000.0                       NaN  master's degree (non-professional)
# 130  75000.0                       NaN      some college credit, no degree
# 159      NaN  Full-Stack Web Developer      some college credit, no degree
# 188      NaN                       NaN      some college credit, no degree
#
#     SchoolMajor
# 93      Biology
# 97        Music
# 130         NaN
# 159         NaN
# 188         NaN
#
# [5 rows x 21 columns]

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees
attendees_per_bootcamp = pd.DataFrame(attended_df["BootcampName"].value_counts())
#attendees_per_bootcamp.head()

# INDEX MUST be RESET in order to filter or merge this DataFrame
attendees_per_bootcamp.reset_index(inplace = True)

# rename the two columns:
   # one with the bootcamp name, and
   # one with the number of respondents who attended each bootcamp

attendees_per_bootcamp.columns = ["BootcampName", "Attendee Count"]
attendees_per_bootcamp.head()
# Out:
#             BootcampName  Attendee Count
# 0       General Assembly              90
# 1        Flatiron School              54
# 2           Dev Bootcamp              48
# 3          The Iron Yard              40
# 4  Prime Digital Academy              30

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp
recommended_df = attended_df.loc[attended_df["BootcampRecommend"] == "Yes", :]
#recommended_df.head()

recommend_bootcamp = pd.DataFrame(recommended_df["BootcampName"].value_counts())
#recommend_bootcamp.head()

# again: INDEX MUST be RESET in order to filter or merge this DataFrame
recommend_bootcamp = recommend_bootcamp.reset_index()

recommend_bootcamp.columns = ['BootcampName', 'Number of Recommenders']
recommend_bootcamp.head()
# Out:
#        BootcampName  Number of Recommenders
# 0  General Assembly                      70
# 1   Flatiron School                      50
# 2      Dev Bootcamp                      41
# 3     The Iron Yard                      31
# 4      Hack Reactor                      27

# %%
# MERGE the two created data frames on the name of the bootcamp

merged_df = pd.merge(attendees_per_bootcamp, recommend_bootcamp, on="BootcampName")
merged_df.head()
# Out:
#             BootcampName  Attendee Count  Number of Recommenders
# 0       General Assembly              90                      70
# 1        Flatiron School              54                      50
# 2           Dev Bootcamp              48                      41
# 3          The Iron Yard              40                      31
# 4  Prime Digital Academy              30                      25

# %%
# Calculate percentage of each bootcamp's students who are recommenders

merged_df["% Recommended"] = merged_df["Number of Recommenders"]/ merged_df["Attendee Count"] *100
merged_df = merged_df.sort_values(by="% Recommended", ascending=False).round(2)

merged_df["% Recommended"] = merged_df["% Recommended"].map("{:,.2f}%".format)
merged_df
# Out:
#                 BootcampName  Attendee Count  Number of Recommenders  \
# 115           Code Institute               1                       1
# 101  Science to Data Science               1                       1
# 100    Austin Coding Academy               1                       1
# 99                     codeU               1                       1
# 98          CodeCraft School               1                       1
# 97         Founders & Coders               1                       1
# 96                Stackademy               1                       1
# 95               Coder's Lab               1                       1
# 44        Academia de Código               4                       4
# 94                  Betamore               1                       1
# 93                  Le Wagon               1                       1
# 47               devCodeCamp               4                       4
# 92         Ruby On The Beach               1                       1
# 91                Code Union               1                       1
# 90             Coder Foundry               1                       1
# 89               DESIGNATION               1                       1
# 88         Omaha Code School               2                       2
# 87                  AcadGild               2                       2
# 86         Telegraph Academy               2                       2
# 85            BoiseCodeWorks               2                       2
# 56      Grace Hopper Academy               3                       3
# 83      Eleven Fifty Academy               2                       2
# 81           Codecademy Labs               2                       2
# 79             We Got Coders               2                       2
# 61                Dev League               3                       3
# 78              Code Platoon               2                       2
# 77       CODEcamp Charleston               2                       2
# 76             Coder Factory               2                       2
# 73             DigitalCrafts               2                       2
# 66              Grand Circus               3                       3
# ..                       ...             ...                     ...
# 14               Coding Dojo              18                      11
# 37             Bitmaker Labs               5                       3
# 26                    Codeup              10                       6
# 41                10x.org.il               5                       3
# 40         CodeCore Bootcamp               5                       3
# 30         Startup Institute               7                       4
# 13                 Galvanize              20                      11
# 21               Coder Camps              11                       6
# 10                   Bloc.io              21                      11
# 28            4Geeks Academy               8                       4
# 36                   Wyncode               6                       3
# 70            PDX Code Guild               2                       1
# 42                 Codesmith               4                       2
# 84             Fire Bootcamp               2                       1
# 74             Digital House               2                       1
# 75     Mobile Makers Academy               2                       1
# 80              LearningFuze               2                       1
# 43              Bit Bootcamp               4                       2
# 82                     Metis               2                       1
# 53            Camp Code Away               4                       2
# 51                 Devschool               4                       2
# 49                 RefactorU               4                       2
# 71                 HackerYou               2                       1
# 57                tradecraft               3                       1
# 59              Coding House               3                       1
# 60       Zip Code Wilmington               3                       1
# 65                  V School               3                       1
# 68            Starter League               3                       1
# 58            We Can Code IT               3                       1
# 54            Codify Academy               4                       1
#
#     % Recommended
# 115       100.00%
# 101       100.00%
# 100       100.00%
# 99        100.00%
# 98        100.00%
# 97        100.00%
# 96        100.00%
# 95        100.00%
# 44        100.00%
# 94        100.00%
# 93        100.00%
# 47        100.00%
# 92        100.00%
# 91        100.00%
# 90        100.00%
# 89        100.00%
# 88        100.00%
# 87        100.00%
# 86        100.00%
# 85        100.00%
# 56        100.00%
# 83        100.00%
# 81        100.00%
# 79        100.00%
# 61        100.00%
# 78        100.00%
# 77        100.00%
# 76        100.00%
# 73        100.00%
# 66        100.00%
# ..            ...
# 14         61.11%
# 37         60.00%
# 26         60.00%
# 41         60.00%
# 40         60.00%
# 30         57.14%
# 13         55.00%
# 21         54.55%
# 10         52.38%
# 28         50.00%
# 36         50.00%
# 70         50.00%
# 42         50.00%
# 84         50.00%
# 74         50.00%
# 75         50.00%
# 80         50.00%
# 43         50.00%
# 82         50.00%
# 53         50.00%
# 51         50.00%
# 49         50.00%
# 71         50.00%
# 57         33.33%
# 59         33.33%
# 60         33.33%
# 65         33.33%
# 68         33.33%
# 58         33.33%
# 54         25.00%
#
# [116 rows x 4 columns]

# %%
# Export to excel and remove index
merged_df.to_excel("output/Bootcamppart2.xlsx", index=False)
